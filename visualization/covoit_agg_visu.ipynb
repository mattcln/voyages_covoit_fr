# %%
import pandas as pd
import os
import plotly.express as px
from datetime import datetime

# %%
in_relative_path = "../outputs/"
in_absolute_path = os.path.abspath(os.path.join(os.getcwd(), in_relative_path))

df = pd.read_csv(f"{in_absolute_path}/reduced_concat_covoit.csv")
df
# Out:
#      journey_start_date  nb_passagers  nb_trajets  total_distance
# 0            2019-02-04             1           1           10047
# 1            2019-02-05             1           1           10047
# 2            2019-02-06             1           1           10047
# 3            2019-02-07             1           1           10047
# 4            2019-02-08             1           1           10047
# ...                 ...           ...         ...             ...
# 1961         2024-07-27         14626       12602       311542937
# 1962         2024-07-28         12783       10941       296147659
# 1963         2024-07-29         28732       24113       674917363
# 1964         2024-07-30         30628       25687       718617813
# 1965         2024-07-31         27408       23114       636060819
#
# [1966 rows x 4 columns]

# %% [markdown]
# # Sur les plateformes

# %%
fig = px.line(df, x="journey_start_date", y="nb_passagers", title='Evolution du nombre de trajets de covoiturage quotidien (en utilisant une plateforme)')
fig.add_vline(x=datetime.strptime("2023-01-01", "%Y-%m-%d").timestamp() * 1000, line_width=3, line_dash="dash", annotation_text="Nouvelle prime de 100€", line_color="green", annotation_font_color="green")
fig.show()
# Out:
# <div>                            <div id="af34e84b-2221-4b5c-857f-adcc8b047971" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af34e84b-2221-4b5c-857f-adcc8b047971")) {                    Plotly.newPlot(                        "af34e84b-2221-4b5c-857f-adcc8b047971",                        [{"hovertemplate":"journey_start_date=%{x}\u003cbr\u003enb_passagers=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2019-02-04","2019-02-05","2019-02-06","2019-02-07","2019-02-08","2019-02-18","2019-02-19","2019-02-20","2019-02-21","2019-02-22","2019-02-25","2019-02-26","2019-02-27","2019-02-28","2019-03-04","2019-03-05","2019-03
# ...

# %% [markdown]
# # En prenant compte des trajets hors-plateforme
# D'après [Comprendre le covoiturage quotidien en France](https://observatoire.covoiturage.gouv.fr/observatoire/comprendre-covoiturage-quotidien/), 96% des trajets covoiturés le sont de manière informelle.
# Il nous reste donc à multiplier les résultats par 25 pour obtenir les chiffres approximatifs du covoiturage en France.

# %%
df["nb_passagers"] = df["nb_passagers"] * 25
df["nb_trajets"] = df["nb_trajets"] * 25
df["total_distance"] = df["total_distance"] * 25

# %%
fig = px.line(df, x="journey_start_date", y="nb_passagers", title='Evolution du nombre de trajets de covoiturage quotidien (plateforme + hors-plateforme)')
fig.show()
# Out:
# <div>                            <div id="be9da3e1-56b9-4863-8c29-592eef52f6e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be9da3e1-56b9-4863-8c29-592eef52f6e9")) {                    Plotly.newPlot(                        "be9da3e1-56b9-4863-8c29-592eef52f6e9",                        [{"hovertemplate":"journey_start_date=%{x}\u003cbr\u003enb_passagers=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2019-02-04","2019-02-05","2019-02-06","2019-02-07","2019-02-08","2019-02-18","2019-02-19","2019-02-20","2019-02-21","2019-02-22","2019-02-25","2019-02-26","2019-02-27","2019-02-28","2019-03-04","2019-03-05","2019-03
# ...

# %% [markdown]
# Chaque semaine, on remarque un pic le mardi et une baisse significative (~66%) le week-end.

# %%
fig = px.line(df, x="journey_start_date", y="total_distance", title='Evolution de la distance total en covoiturage au quotidien (plateforme + hors-plateforme)')
fig.show()
# Out:
# <div>                            <div id="7525aacf-f41f-418d-92be-75d8123b60a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7525aacf-f41f-418d-92be-75d8123b60a6")) {                    Plotly.newPlot(                        "7525aacf-f41f-418d-92be-75d8123b60a6",                        [{"hovertemplate":"journey_start_date=%{x}\u003cbr\u003etotal_distance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2019-02-04","2019-02-05","2019-02-06","2019-02-07","2019-02-08","2019-02-18","2019-02-19","2019-02-20","2019-02-21","2019-02-22","2019-02-25","2019-02-26","2019-02-27","2019-02-28","2019-03-04","2019-03-05","2019-
# ...
